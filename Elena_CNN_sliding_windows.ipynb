# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaManari/MLPNS_EManari/blob/main/Elena_CNN_sliding_windows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTANTE: Impostare come runtime GPU per accelerare il training
#e non metterci una vita

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importo i vari pacchetti

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
#per ragioni estetiche sistemo alcuni parametri visuali del plotting
#sistemo la dimensione delle immagini
#non voglio fare interpolazioni sulle immagini
#metto una mappa di colori in bianco e nero

plt.rcParams["figure.figsize"] = [10, 8]
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"

# %%
cd /content/drive/MyDrive/MLPNS2023
# Out:
# /content/drive/MyDrive/MLPNS2023

# %%
ls
# Out:
# kaggleTitanic/             wine.data    wine.data.2  wine.names.1
# spm-20210427T111354Z-001/  wine.data.1  wine.names   wine.names.2

# %%
# !unzip spm-20210427T111354Z-001.zip
# Out:
# unzip:  cannot find or open spm-20210427T111354Z-001.zip, spm-20210427T111354Z-001.zip.zip or spm-20210427T111354Z-001.zip.ZIP.

# %%
#sono tutti numpy arrays, e la funzione per leggerli è:
#np.load
#invece per salvarli si usa:
#np.save

#carichiamo i training data, utilizzeremo questo come training set
#e lo spacchetteremo in due sets come training set e test set
data = np.load('spm-20210427T111354Z-001/spm/train_good_all.npy')

# %%
data.shape
#sono 1302 di dimensione 64x64
# Out:
# (1302, 64, 64)

# %%
#plotto le prime 8 immagini del mio set di dati giusto per capire
fig, ax = plt.subplots(2, 4, figsize=[10,5], sharex=True, sharey=True)

for ii in range(8):
  ax[ii // 4, ii % 4].imshow(data[ii])

# %% [markdown]
# Voglio costruire un CNN che impari la forma delle molecole e ne riconosca la posizione nelle varie immagini che ho a disposizione.

# %%
plt.hist(data.flatten())
# Out:
# (array([ 254226.,  957465., 1143646., 1050540.,  825288.,  338534.,
#          391059.,  151471.,  179803.,   40960.]),
#  array([-1.07775726e-07, -9.55749615e-08, -8.33741970e-08, -7.11734324e-08,
#         -5.89726678e-08, -4.67719032e-08, -3.45711387e-08, -2.23703741e-08,
#         -1.01696095e-08,  2.03115507e-09,  1.42319196e-08]),
#  <BarContainer object of 10 artists>)

# %%
#la prima cosa che si fa come operazione di preprocessing è creare una 
#operazione normalizzata, come:

# norm= (D - min(D)) / range(D)

#Dove D sono i miei data. Va bene questa normalizzazione in quanto la 
#distribuzione è continua, gaussiana e non ha gaps

norm = (data - data.min(axis=(1, 2), keepdims=True)) / (data.max(axis=(1, 2), keepdims=True) - 
                                                        data.min(axis=(1, 2), keepdims=True))

# %%
norm.min(), norm.max()
# Out:
# (0.0, 1.0)

# %%
norm.shape
# Out:
# (1302, 64, 64)

# %%
#passiamo al codice la posizione delle molecole

#leggo le labels positive
pos = np.load('spm-20210427T111354Z-001/spm/spm_struct_pos.npy')
#leggo le labels negative
neg = np.load('spm-20210427T111354Z-001/spm/spm_struct_neg.npy')

# %%
pos.shape, neg.shape
# Out:
# ((500, 3), (500, 3))

# %%
pos[0]
# Out:
# array([30, 25, 51])

# %%
pos.max(axis=0)
# Out:
# array([  62,   62, 1300])

# %%
#testing per vedere come è stata fatta la posizione delle molecole e dei
#loro centri, prendo l'immagine 51 ad esempio
plt.imshow(norm[pos[0][2]])
plt.plot(pos[0][1], pos[0][0], 'o')

# %% [markdown]
# Per semplificare le cose, creo delle immagini che contengono solo le molecole e delle immagini che non contengono le molecole, in maniera tale da insegnare al neural network come distinguere una molecola. Creiamo uno sliding windows detector.
#
# Creerò dei francobolli (delle mini immagini) centrate attorno alla molecola, con dimensione circa 20 x 20, e metterò come hyperparameter wid=10.

# %%
wid = 10
stmp_pos = []
for ii in range(pos.shape[0]):
  trow, tcol, tind = pos[ii]
  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_pos.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid,])

stmp_pos = np.array(stmp_pos)

# %%
plt.imshow(stmp_pos[0])

# %% [markdown]
# Ho costruito un francobollo contenente la molecola, chiamato stmp_pos.

# %%
wid = 10
stmp_neg = []

for ii in range(pos.shape[0]):
  trow, tcol, tind = neg[ii]
  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_neg.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid,])

stmp_neg = np.array(stmp_neg)

# %%
plt.imshow(stmp_neg[0])

# %% [markdown]
# Ho costruito un francobollo non contenente una molecola, chiamato stmp_neg.

# %%
#vediamo una serie delle mie annotazioni positive

fig, ax = plt.subplots(10, 10)
for ii in range(100):
    ax[ii // 10, ii % 10].imshow(stmp_pos[ii])
    ax[ii // 10, ii % 10].axis("off")

# %%
#vediamo una serie delle mie annotazioni negative 

fig, ax = plt.subplots(10, 10)
for ii in range(100):
    ax[ii // 10, ii % 10].imshow(stmp_neg[ii])
    ax[ii // 10, ii % 10].axis("off")

# %%
#faccio il training test, settando le feature e il target
#nel target assegno con valore 0 le feature negative senza molecola
#e valore 1 per la feature positive con la molecola
feat = np.concatenate((stmp_neg, stmp_pos), axis=0)
targ = np.concatenate((np.zeros(stmp_neg.shape[0]), 
                      np.ones(stmp_pos.shape[0])))

# %%
stmp_neg.shape, stmp_pos.shape

#più o meno ho lo stesso numero di positive
#and negative stamps.
# Out:
# ((485, 20, 20), (389, 20, 20))

# %%
train_test_split?

# %%
#devo assicurarmi di mescolare i dati, perché altrimenti il neural
#network potrebbe imparare che i primi dati che gli arrivano sono positive
#e gli ultimi che gli arrivano sono i negative
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ,
                                                      random_state=302, shuffle=True)

feat_tr.shape
# Out:
# (655, 20, 20)

# %%
#devo cambiare dimensione dell'array per fargli capire che le mie
#immagini sono in bianco e nero, in genere ci vogliono tre assi R,G,B
#per i colori, in questo caso ho (20, 20), ma voglio (20, 20, 1)

feat_tr = np.expand_dims(feat_tr, axis=3)
feat_te = np.expand_dims(feat_te, axis=3)
feat_tr.shape
# Out:
# (655, 20, 20, 1)

# %% [markdown]
# #Creiamo il Convolutional Neural Network:
#
# Architettura del network:
#
# - conv2d 16 neurons
# - maxpool2d 2x2
# - conv2d 32 neurons
# - maxpool2d 2x2
# - flatten
# - dense 64 neurons
# - dense 2 neurons (questo perché avrò due risultati)
#
# kernel_size -> dimensione della feature map
#
# input_shape -> dobbiamo dire la shape dei dati (20x20x1)
#
# kernel_regilarizer -> diamo una
# regolarizzazione utile per evitare overfitting

# %%
keras.layers.Dense?

# %%
layer1 = keras.layers.Conv2D(16, kernel_size=(5, 5), padding="same", 
                             activation="relu", 
                             input_shape=(2 * wid, 2 * wid, 1), #needed in the first layer only
                             kernel_regularizer=keras.regularizers.l2(0.001))

layer2 = keras.layers.MaxPool2D(2)

layer3 = keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same", 
                             activation="relu", 
                             kernel_regularizer=keras.regularizers.l2(0.001))

layer4 = keras.layers.MaxPool2D(2)

layer5 = keras.layers.Flatten()

#l'activation function nel layer6 è opzionale, potrebbe essere relu oppure
#anche linear
layer6 = keras.layers.Dense(64, activation="relu",
                            kernel_regularizer=keras.regularizers.l2(0.001))

#softmax restituisce valori binari, 0 oppure 1
layer7 = keras.layers.Dense(2, activation="softmax")


layers = [layer1, layer2, layer3, layer4, layer5, layer6, layer7]
model = keras.Sequential(layers)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 20, 16)        416
#
#  max_pooling2d (MaxPooling2D  (None, 10, 10, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 32)        12832
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 64)                51264
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 64,642
# Trainable params: 64,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
#abbiamo 64000 parametri, un po' più serio

keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
#per optimizer usiamo adam di default
#mettiamo una loss function categorica, in quanto i dati finali sono
#categorici, con sparse_categorical_crossentropy ed è una loss function
#stile softmax, e usiamo come metrica accuracy

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
              metrics="accuracy")

# %%
#facciamo il fitting con una variabile history per fare un plot della
#loss function via via che itero. Scelgo come epoche 50, che va bene per
#questo problema semplice. La batch size serve per ridurre l'overfitting.
#validation split serve per fare una valutazione interna sui dati

history = model.fit(feat_tr, targ_tr, epochs=50,
                    batch_size=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 11s 41ms/step - loss: 0.7185 - accuracy: 0.7029 - val_loss: 0.5581 - val_accuracy: 0.9394
# Epoch 2/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5269 - accuracy: 0.8998 - val_loss: 0.3819 - val_accuracy: 0.8788
# Epoch 3/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3973 - accuracy: 0.9236 - val_loss: 0.3337 - val_accuracy: 0.9091
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3110 - accuracy: 0.9236 - val_loss: 0.3143 - val_accuracy: 0.9091
# Epoch 5/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2817 - accuracy: 0.9236 - val_loss: 0.3060 - val_accuracy: 0.8939
# Epoch 6/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2434 - accuracy: 0.9474 - val_loss: 0.2348 - val_accuracy: 0.9242
# Epoch 7/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2118 - accuracy: 0.9626 - val_loss: 0.2277 - val_accuracy: 0.9242
# Epoch 8/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1849 - accuracy: 0.9762 - val_loss: 0.2117 - val_accuracy: 0.9394
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1669 - accuracy: 0.9813 - val_loss: 0.2077 - val_accuracy: 0.9394
# Epoch 10/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1616 - accuracy: 0.9796 - val_loss: 0.1724 - val_accuracy: 0.9545
# Epoch 11/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1895 - accuracy: 0.9728 - val_loss: 0.2112 - val_accuracy: 0.9545
# Epoch 12/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1605 - accuracy: 0.9762 - val_loss: 0.1785 - val_accuracy: 0.9545
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1355 - accuracy: 0.9898 - val_loss: 0.1629 - val_accuracy: 0.9545
# Epoch 14/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1293 - accuracy: 0.9864 - val_loss: 0.1562 - val_accuracy: 0.9697
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1309 - accuracy: 0.9864 - val_loss: 0.1660 - val_accuracy: 0.9394
# Epoch 16/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1227 - accuracy: 0.9898 - val_loss: 0.1678 - val_accuracy: 0.9697
# Epoch 17/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1131 - accuracy: 0.9915 - val_loss: 0.1637 - val_accuracy: 0.9394
# Epoch 18/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1084 - accuracy: 0.9932 - val_loss: 0.1369 - val_accuracy: 0.9545
# Epoch 19/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1063 - accuracy: 0.9898 - val_loss: 0.1399 - val_accuracy: 0.9697
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1005 - accuracy: 0.9915 - val_loss: 0.1436 - val_accuracy: 0.9545
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1068 - accuracy: 0.9898 - val_loss: 0.1581 - val_accuracy: 0.9394
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1011 - accuracy: 0.9915 - val_loss: 0.1396 - val_accuracy: 0.9394
# Epoch 23/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0989 - accuracy: 0.9898 - val_loss: 0.1721 - val_accuracy: 0.9545
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0970 - accuracy: 0.9915 - val_loss: 0.1604 - val_accuracy: 0.9545
# Epoch 25/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0868 - accuracy: 0.9915 - val_loss: 0.1258 - val_accuracy: 0.9697
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0899 - accuracy: 0.9966 - val_loss: 0.1192 - val_accuracy: 0.9848
# Epoch 27/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0841 - accuracy: 0.9966 - val_loss: 0.1520 - val_accuracy: 0.9545
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0822 - accuracy: 0.9966 - val_loss: 0.1164 - val_accuracy: 0.9697
# Epoch 29/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0894 - accuracy: 0.9949 - val_loss: 0.1208 - val_accuracy: 0.9697
# Epoch 30/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0816 - accuracy: 0.9932 - val_loss: 0.1105 - val_accuracy: 0.9697
# Epoch 31/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0755 - accuracy: 0.9983 - val_loss: 0.1269 - val_accuracy: 0.9545
# Epoch 32/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0736 - accuracy: 0.9983 - val_loss: 0.1178 - val_accuracy: 0.9697
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0774 - accuracy: 0.9949 - val_loss: 0.1112 - val_accuracy: 0.9848
# Epoch 34/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0806 - accuracy: 0.9949 - val_loss: 0.1225 - val_accuracy: 0.9697
# Epoch 35/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0827 - accuracy: 0.9949 - val_loss: 0.0898 - val_accuracy: 0.9848
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0760 - accuracy: 0.9966 - val_loss: 0.1593 - val_accuracy: 0.9697
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0730 - accuracy: 0.9966 - val_loss: 0.1196 - val_accuracy: 0.9394
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0706 - accuracy: 0.9949 - val_loss: 0.1069 - val_accuracy: 0.9697
# Epoch 39/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0685 - accuracy: 0.9983 - val_loss: 0.1059 - val_accuracy: 0.9697
# Epoch 40/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0641 - accuracy: 0.9983 - val_loss: 0.1000 - val_accuracy: 0.9848
# Epoch 41/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0616 - accuracy: 0.9983 - val_loss: 0.0953 - val_accuracy: 0.9697
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0666 - accuracy: 0.9983 - val_loss: 0.0998 - val_accuracy: 0.9697
# Epoch 43/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0677 - accuracy: 0.9966 - val_loss: 0.1198 - val_accuracy: 0.9545
# Epoch 44/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9545
# Epoch 45/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0617 - accuracy: 0.9983 - val_loss: 0.0996 - val_accuracy: 0.9697
# Epoch 46/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0616 - accuracy: 0.9983 - val_loss: 0.1107 - val_accuracy: 0.9697
# Epoch 47/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0644 - accuracy: 0.9983 - val_loss: 0.1020 - val_accuracy: 0.9697
# Epoch 48/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0594 - accuracy: 0.9983 - val_loss: 0.1111 - val_accuracy: 0.9545
# Epoch 49/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9697
# Epoch 50/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9545

# %%
history.history["val_accuracy"]
# Out:
# [0.939393937587738,
#  0.8787878751754761,
#  0.9090909361839294,
#  0.9090909361839294,
#  0.8939393758773804,
#  0.9242424368858337,
#  0.9242424368858337,
#  0.939393937587738,
#  0.939393937587738,
#  0.9545454382896423,
#  0.9545454382896423,
#  0.9545454382896423,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.939393937587738,
#  0.9696969985961914,
#  0.939393937587738,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9545454382896423,
#  0.939393937587738,
#  0.939393937587738,
#  0.9545454382896423,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9848484992980957,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9848484992980957,
#  0.9696969985961914,
#  0.9848484992980957,
#  0.9696969985961914,
#  0.939393937587738,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9848484992980957,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9545454382896423,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9696969985961914,
#  0.9545454382896423,
#  0.9696969985961914,
#  0.9545454382896423]

# %%
plt.plot(history.history["loss"], label= "training")
plt.plot(history.history["val_loss"], label="validation")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

# %% [markdown]
# Sembra ci sia un leggero overfitting poiché pare che vi sia una leggera distanza tra training curve e validation curve. Il fatto che vi siano loss curves noisy è perché è un problema difficile. Spesso per ridurre il noise converrebbe ridurre il learning rate.

# %%
plt.plot(history.history["accuracy"], label= "training")
plt.plot(history.history["val_accuracy"], label="validation")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()

# %% [markdown]
# Anche l'accuracy va di pari passo con la loss function.

# %%
loss_tr, acc_tr = model.evaluate(feat_tr, targ_tr)
loss_te, acc_te = model.evaluate(feat_te, targ_te)
print("{:.2f}, {:.2f}, {:.2f}, {:.2f}".format(loss_tr, acc_tr, loss_te, acc_te))
# Out:
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0580 - accuracy: 0.9939
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0995 - accuracy: 0.9909
# 0.06, 0.99, 0.10, 0.99

# %% [markdown]
# Finora abbiamo creato un neural network che riconosce un poster stamp di dimensione 20 x 20 che studia se quell'oggetto è una molecola oppure no. Siccome abbiamo una classificazione probabilistica, dobbiamo avere un risultato di più alta confidenza via via che ci avviciniamo al centro della molecola. Creiamo ora un poster stamp suddividendo in blocchi 20x20 tutte le immagini.

# %%
pos[0]
# Out:
# array([30, 25, 51])

# %%
plt.imshow(norm[51])

# %%
#facciamo un'immagine di prova per vedere come separo questa immagine
img = norm[51].copy()

# %%
wid
# Out:
# 10

# %%
nrow, ncol = img.shape
#costruisco i miei stamps 20x20 come array
#stamps= np.zeros((N_images, N_rows, N_columns))
stamps = np.zeros(((nrow - wid * 2) * (ncol - wid * 2), 2 * wid, 2 * wid))
stamps.shape

#aggiungo un counter kk
kk = 0
for ii in range(wid, nrow - wid): #loop on rows
  for jj in range(wid, ncol - wid): #loop on cols
    stamps[kk] = img[ii-wid:ii+wid, jj-wid:jj+wid]
    kk += 1

feat_stmp = np.expand_dims(stamps, axis=3)

# %%
plt.imshow(feat_stmp[0])

# %%
pred = model.predict(feat_stmp)
# Out:
# 61/61 [==============================] - 0s 2ms/step
