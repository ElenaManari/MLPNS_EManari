# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaManari/MLPNS_EManari/blob/main/vis_elena_manari_def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modificare un grafico secondo le regole di Tufte

# %% [markdown]
# Come grafico da modificare ho scelto la mappa di Poincaré per il sistema di Henon Heiles, che descrive il movimento di una stella in un potenziale galattico. Il sistema da risolvere è di tipo non lineare.
# I grafici sono stati realizzati con Matlab a seguito dell'integrazione numerica con Runge Kutta 4 delle equazioni differenziali che governano la dinbamica del sistema.
#
# # Grafico iniziale
# ![henon.png](data:image/png;base64,...)

# %% [markdown]
# # Grafico modificato
#
# ![hhmod2.jpg](data:image/jpeg;base64,...)
# Rispetto al grafico di partenza ho fatto le seguenti modifiche:
#
# 1) Ingrandito i punti del grafico, fatto in modo che i colori diventassero più facilmente identificabili mettendo lo sfondo togliendo la griglia
# 2) Ho cercato colori che tutelassero la colorblindness
# 3) Messo numeri interni negli assi x e y
# 4) Inserito la legenda per le diverse orbite per l'integrazione numerica

# %% [markdown]
# # Ecco il file txt con i codici per la realizzazione dei grafici
#
# https://drive.google.com/file/d/1rcRSelXkAbn1nSlt04sm_978A0Rawf1I/view?usp=share_link
